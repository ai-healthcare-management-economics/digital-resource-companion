# %% [markdown]
# # AIHE-PY40 - Lifecycle Decision-State and Trigger Review
#
# Digital Resource Companion V1.0. The bundled data are synthetic and must be replaced with governed local evidence before institutional use.

# %% [markdown]
# **Related resources:** AIHE-D02; AIHE-D03; AIHE-D04; AIHE-D05; AIHE-CASE12; AIHE-CASE09B;
#
# Run the next cell from the repository or downloaded module folder. The script writes reproducible CSV and JSON outputs to `outputs/generated`.

# %%
from pathlib import Path
import subprocess, sys

module_dir = Path.cwd()
while module_dir != module_dir.parent and not (module_dir / 'python').exists():
    module_dir = module_dir.parent
script = module_dir / 'python' / '40_lifecycle_decision_state_and_trigger_review.py'
output_dir = module_dir / 'outputs' / 'generated'
subprocess.run([sys.executable, str(script), '--output-dir', str(output_dir)], check=True)
print(f'Outputs written to {output_dir}')
